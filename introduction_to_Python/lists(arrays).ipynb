# %% [markdown]
# Arrays / Lists in Python for DSA Journey

# %%
array = [2,4,5,6]
print(array)
# Out:
# [2, 4, 5, 6]

# %%
array.append(7)
print(array)
array.insert(0,1)
print(array)
# Out:
# [2, 4, 5, 6, 7]
# [1, 2, 4, 5, 6, 7]
